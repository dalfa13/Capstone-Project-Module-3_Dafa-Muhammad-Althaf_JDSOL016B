# %% [markdown]
# # **SAUDI USED CARS -Capstone Project 3 🚗💰🚗💰**
# ---
#
# Dafa Muhammad Althaf (JDSOL016B)
# ---
#
# ### **Business Problem Understanding**
# ---
#
# #####  **Context**
#
# Negara Arab saudi merupakan salah satu negara yang paling banyak di kunjungi terutama indonesia, menurut [Kompas.com](https://travel.kompas.com/read/2024/03/02/101222327/arab-saudi-dikunjungi-lebih-dari-100-juta-wisatawan-tahun-2023#:~:text=Ni%20Nyoman%20Wira%20Widyanti&text=KOMPAS.com%20%2D%20Arab%20Saudi%20menerima,1/3/2024&text=Adapun%20dilansir%20dari%20laman%20resminya,Tiket%20Mulai%20Rp%20144.000%2Dan). Tahun 2023 Arab Saudi di kunjungi lebih dari 100 juta wisatawan, setidaknya terdapat 2 juta perjalanan masayarakat indonesia yang pergi berpergian ke Arab Saudi, setiap pelancong tentu membutuhkan kendaraan saat berpergian, kendaraan tersebut tentunya harus dilakukan dari penyewaan sehingga hal tersebut dapat menjadi prospek bisnis yang menunguntungkan.
#
# Penyewaan mobil di luar negri umunya sangat sulit di lakukan karena kepercayaan antara penyewa dan pemberi sewa sangat lah memburuhkan komunikasi yang baik. banyak kasus yang terjadi seperti penipuan yang ketika sudah di bayar mobil tidak kunjung datang. Menjadi penyewa mobil bagi masyarakat indonesia yang di sewakaon oleh orang Indonesia di Arab Saudi akan sangat memudahkan komunikasi antar penyewa dan pemberi sewa sehingga akan meminimalisir kesalahan dalam komunikasi dan penipuan terutama bagi wisatawan yang baru pertama kali pergi ke Arab Saudi.Pasar mobil bekas di Arab Saudi merupakan sektor yang signifikan karena tingginya permintaan kendaraan pribadi, didorong oleh faktor-faktor seperti terbatasnya transportasi umum dan kebutuhan mobilitas di negara dengan jarak antar kota yang luas. Pasar ini mencakup berbagai jenis kendaraan, mulai dari sedan dan SUV hingga mobil mewah dan truk, masing-masing dengan tingkat depresiasi, biaya pemeliharaan, dan nilai jual kembali yang berbeda.
#
# Banyaknya mobil bekas yang ada di Arab Saudi dapat di manfaatkan oleh pelaku bisnis untuk meminimalisir anggaran pengeluaran dalam pembelian mobil, mobil bekas umumnya memiliki harga yang jauh lebih murah di bandingkan mobil baru sehingga membeli mobil bekasbisa menjadi opsi bagi pelaku usaha yang ingin menyewakan mobilnya untuk disewakan kepada wisatawan.
# Dalam konteks ini, bisnis yang terlibat dalam pasar mobil bekas, seperti dealer, platform online, dan perusahaan pembiayaan, menghadapi beberapa tantangan. Tantangan tersebut termasuk menentukan harga mobil bekas secara akurat, memprediksi kemungkinan mobil terjual dalam periode waktu tertentu, dan memahami faktor-faktor yang memengaruhi keputusan pembeli untuk membeli mobil bekas untuk mematikan mobil tersebut akan tetap menguntungkan saat akan di jual kembali setal selesai di gunakan. dari hal tersebut nantinya pebisnis dengan dapat menyewakan mobil yang masih bagus dengan harga yang sesuai.
#
# ---
# #####  **Problem Statment & Goal**
#
# Seorang pengusaha dari Indonesia melihat peluang usaha dari banyaknya wisatawan indonesia yang datang ke Arab Saudi yang berangkat dari keresahan wisatawan Indonesia yang terkendala dalam melakukan penyewaan alat transportasi. maka dari itu pengusaha tersebut ingin membeli mobil untuk nantinya di sewakan oleh para wisatawan yang membutuhkan kendaraan. perbedaan nilai mata uang antara Riyal dan Rupiah menjadi pertimbangan dalam membeli mobil,maka pengusaha memutuskan membeli mobil bekas yang harga jualnya jauh lebih murah. Untuk mengetahui berapa harga yang sesuai dengan kualitas mobil dan saat mobil diperbarui kita mengetahui berapa mobil lama yang akan kita jual nantinya.
#
# Dari data yang nantinya akan di analisis fitur-fitur yang di gunakan akan dapat memberikan nominal harga mobil yang natinya menjadi acuan saat membeli mobil dan saat menjual mobil tersebut saat ingin melakukan perbaruan armada. Harga mobil yang menjadi target pada mobel nantinya dapat menjadi bahan pertimbangan pengusaha tersebut dalam melakukan pembelian mobil yang sesuai oleh kebutuhan sehingga dapat menyesuaikan dengan mobil apa saja yang akan di beli agar dapat disewakan sesuai target permintaan penyewa mobil.
#
# ---
# #####  **Analytic Approach**
#
# Analisis data yang di gunakan untuk menentukan Harga (Price) sebagai target akan di lihat dari pola atau fitur yang dimiliki pada data. Fitur tersebut nantinya akan di liat jenis datanya untuk menentukan *Encoding* atau mengubah data menjadi nilai numerikal yang dapat memudahkan dalam melakukan perintah dalam analisis.
#
# Selanjutnya nanti kita akan membangun model, model yang akan di pilih merupakan model yang digunakan untuk tipe data dan target Regresi. Nantinya kita akan menggunakan beberapa model untuk menghasilakan harga mobil yang sesuai dengan kriteria. selain itu terdapat **Matrix Evaluation** yang di gunakan antara MSE, RMSE, MAPE, MPSE, MSLE,& R-squared yang nantinya di tentukan saat sudah mengetahu karakteristik data.
#
# ---
# #####  **Data Understanding**
# - Data yang di analisis merupakan data [Used Saudi Used Cars](https://drive.google.com/file/d/1Tr4YT5dmgwTrXLvIqZ4diBf5z8K6JjrR/view?usp=drive_link)
# - Terdapat 11 kolom yang memberikan informasi terkait mobil tersebut
#
# ---
# #### **Attribute Information**
#
# | Attribute | Data Type| Description |
# | --- | --- | --- |
# | Type | Object | Type of used car |
# | Region | Object | The region in which the used car was offered for sale |
# | Make | Object | The company name|
# | Gear_Type | Object | Gear type size of used car (Manual/Autometic)|
# | Origin | Object | Origin of Used Cars(Gulf / Saudi / Other) |
# | Options | Object | Options of used car (Full Options / Semi-Full / Standard)|
# | Year | Int | Manufacturing Year (The year Cars was built)
# | Enginee_Size | Float | The engine size of used car |
# | Mileage | Int | Mileage of used car  (The distance Cars to used Before, Mesured In Miles)|
# | Negotiable | Bool | True if the price is 0, that means it is negotiable|
# | Price | int | Used Cars Price (Target)|

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import library untuk modeling
from sklearn.model_selection import train_test_split, cross_val_score, RandomizedSearchCV, GridSearchCV, KFold

# Import Library for Transformed Data Features
import category_encoders as ce
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, MinMaxScaler, RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV, train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, f1_score
from sklearn.metrics import RocCurveDisplay, PrecisionRecallDisplay, confusion_matrix, recall_score, fbeta_score, make_scorer

# Import Libraries for Modeling
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost.sklearn import XGBRegressor
from xgboost.sklearn import XGBClassifier
from sklearn.compose import TransformedTargetRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Import Matrix for Evaluation
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error,mean_squared_log_error

from imblearn.over_sampling import RandomOverSampler, SMOTE
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.pipeline import Pipeline
import warnings
warnings.filterwarnings('ignore')

# %%
UC = pd.read_csv('data_saudi_used_cars.csv')
UC.head()
# Out:
#           Type          Region        Make  Gear_Type       Origin    Options  \
# 0      Corolla            Abha      Toyota     Manual        Saudi   Standard
# 1        Yukon          Riyadh         GMC  Automatic        Saudi       Full
# 2  Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic       Full
# 3       Optima  Hafar Al-Batin         Kia  Automatic        Saudi  Semi Full
# 4           FJ          Riyadh      Toyota  Automatic        Saudi       Full
#
#    Year  Engine_Size  Mileage  Negotiable   Price
# 0  2013          1.4   421000        True       0
# 1  2014          8.0    80000       False  120000
# 2  2015          5.0   140000       False  260000
# 3  2015          2.4   220000       False   42000
# 4  2020          4.0    49000        True       0

# %% [markdown]
# ### **Exploratory Data Analysis**
# ---

# %%
UC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5624 entries, 0 to 5623
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         5624 non-null   object
#  1   Region       5624 non-null   object
#  2   Make         5624 non-null   object
#  3   Gear_Type    5624 non-null   object
#  4   Origin       5624 non-null   object
#  5   Options      5624 non-null   object
#  6   Year         5624 non-null   int64
#  7   Engine_Size  5624 non-null   float64
#  8   Mileage      5624 non-null   int64
#  9   Negotiable   5624 non-null   bool
#  10  Price        5624 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 445.0+ KB

# %%
UC.describe()
# Out:
#               Year  Engine_Size       Mileage          Price
# count  5624.000000  5624.000000  5.624000e+03    5624.000000
# mean   2014.101885     3.295430  1.509234e+05   53074.058144
# std       5.791606     1.515108  3.828360e+05   70155.340614
# min    1963.000000     1.000000  1.000000e+02       0.000000
# 25%    2012.000000     2.000000  3.800000e+04       0.000000
# 50%    2016.000000     3.000000  1.030000e+05   36500.000000
# 75%    2018.000000     4.500000  1.960000e+05   72932.500000
# max    2022.000000     9.000000  2.000000e+07  850000.000000

# %%
UC.describe(include=object)
# Out:
#                 Type  Region    Make  Gear_Type Origin Options
# count           5624    5624    5624       5624   5624    5624
# unique           347      27      58          2      4       3
# top     Land Cruiser  Riyadh  Toyota  Automatic  Saudi    Full
# freq             269    2272    1431       4875   4188    2233

# %%
# Check unique in each variable
pd.set_option('display.max_colwidth', None)

item = []
for i in UC.columns :
    item.append([i, UC[i].nunique(), UC[i].unique()])

table_unique = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                            data = item)
table_unique
# Out:
#     Column Name  Number of Unique  \
# 0          Type               347
# 1        Region                27
# 2          Make                58
# 3     Gear_Type                 2
# 4        Origin                 4
# 5       Options                 3
# 6          Year                50
# 7   Engine_Size                71
# 8       Mileage              1716
# 9    Negotiable                 2
# 10        Price               467
#
# ...

# %% [markdown]
# ##### **Distribusi Price Used Cars In Arab Saudi**
# ---

# %%
mean_price = UC['Price'].mean()
median_price = UC['Price'].median()

plt.figure(figsize=(7,7))
sns.histplot(UC['Price'], kde=True, bins=100)  # Menggunakan histplot untuk menambah garis
plt.axvline(mean_price, color='red', linestyle='--', label=f'Mean: {mean_price:.2f}')
plt.axvline(median_price, color='blue', linestyle='-', label=f'Median: {median_price:.2f}')

plt.title('Plot Distribusi Price', size=14, weight='bold')
plt.legend()

# %% [markdown]
# Visualisasi plot pada distribusi harga mobil bekas di arab saudi value dari kolom price condong ke arah kanan atau bisa di sebut "Right-Skewed Distribution". hal tersbeut menunjukan skewness positif pada fitur Price (Target)

# %% [markdown]
# **Melakukan Pengecekan Outlier pada fitur numerikal**

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

sns.boxplot(x=UC['Year'], ax=axes[0, 0])
axes[0, 0].set_title('Box Plot of Year')

sns.boxplot(x=UC['Engine_Size'], ax=axes[0, 1])
axes[0, 1].set_title('Box Plot of Engine Size')

sns.boxplot(x=UC['Mileage'], ax=axes[1, 0])
axes[1, 0].set_title('Box Plot of Mileage')

sns.boxplot(x=UC['Price'], ax=axes[1, 1])
axes[1, 1].set_title('Box Plot of Price')

plt.tight_layout()
plt.show()

# %%
# Mengecek nilai Duplikat 
print('Kolom yang memiliki duplikat sebanyak :', sum(UC.duplicated()))
# Out:
# Kolom yang memiliki duplikat sebanyak : 4

# %%
UC.isnull().sum()
# Out:
# Type           0
# Region         0
# Make           0
# Gear_Type      0
# Origin         0
# Options        0
# Year           0
# Engine_Size    0
# Mileage        0
# Negotiable     0
# Price          0
# dtype: int64

# %% [markdown]
# - Dataset terdiri dari 5624 baris data dan 11 kolom/variabel dengan 2 jenis tipe data :
#     - 5 Variabel Numerik : Pice, Mileage, Engine_Size, Year
#     - 7 Variabel Categorical/Object : Type, Region, Make, Gear_Type, Origin, Options, Negotiable
# - Tipe data pada seluruh kolom telah sesuai, namun untuk mempermudah proses analisis dan pemodelan, akan dilakukan Encoding pada variabel kategorikal.
# - Terdapat value `Unknown` dan `other` pada kolom `Origin`, yang berarti tidak di ketahui asal negara importir mobil tersebut, kedua value tersebut dapat di artikan sama karena tidak menjelaskan secara spesifik lokasi.
# - Pada kolom `Type`, `Make`, dan `Origin` Terdapat naman `Other`, kata dapat melakukan pengecekan untuk mengetahui pengaruh nilai other tersebut pada nilai `Price`.
# - Pada variabel Milleage terdapat nilai anomali yang cukup besar yaitu lebih dari 20.000.000, hal tersebut cukup aneh karena mobil dengan jarak tempuh diatas tersebut umumnya tidak akan terjadi.
# - Terdapat Nilai `0` pada kolom `Price`. data tersebut harus kita cari tau apa wajar atau tidak
# - terdapat nilai Outlier pada kolom `Year` dan `Engine_Size` yang masih masih sesuai dengan informasi yang di butuhkan, maka kedua data tersebut tetap dipertahankan.
# - kolom yang terduplikat adalah 4 kolom. 4 kolom tersebut akan kita take out

# %% [markdown]
# ##### 1. Memahami data **`Origin`**

# %%
value_counts =UC['Origin'].value_counts()
value_counts
# Out:
# Origin
# Saudi          4188
# Gulf Arabic     697
# Other           678
# Unknown          61
# Name: count, dtype: int64

# %%
total_data = len(UC)

# persentasi kontribusi per value
persentase = (value_counts/total_data)*100

print(persentase)
# Out:
# Origin
# Saudi          74.466572
# Gulf Arabic    12.393314
# Other          12.055477
# Unknown         1.084637
# Name: count, dtype: float64

# %%
persentase.plot(kind='pie',autopct='%1.1f%%')
plt.title('Persentase Asal Mobil')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - Dari persentasi tersebut diketahui bahwa jika `Other` dan `Unknown` di jadikan satu maka persentasenya tidak akan melebihi yang value yang diketahui **Origin** atau asal mobil tersebut. sehingga nilai tersebut dapat di pertahankan.
# - Mengubah value Other menjadi Unknown untuk memudahkan dalam encoding.

# %%
UC['Origin']=UC['Origin'].replace(['Other'],'Unknown')

# %%
value_counts =UC['Origin'].value_counts()
value_counts
# Out:
# Origin
# Saudi          4188
# Unknown         739
# Gulf Arabic     697
# Name: count, dtype: int64

# %% [markdown]
# ##### 2. Memahami data **`Type`**

# %%
Value_Type = (UC[UC['Type']=='Other'])
print("Jumlah Mobil yang memiliki Type Other :",len(Value_Type))
# Out:
# Jumlah Mobil yang memiliki Type Other : 25

# %% [markdown]
# - Kolom Type adalah kolom yang memuat informasi tentang tipe mobil atau jenis mobil yang keluar dari perusahaan tertentu.
# - Pada Type mobil Used Car di Arab Saudi terdapat 25 mobil yang tidak diketahui tipe atau jenis mobil tersebut
# - Secara skala mungkin data tersebut terlihat kecil dan mungkin tidak berpengaruh, akan tetapi dalam dunia otomotif tipe mobil sangat mempengaruhi harga mobil tersebut. Maka perlu di lakukan pengecekan pengaruh value tersebut pada target analisis kita `(Price)` untuk menentukan apa nilai tersebut harus di *Take-Out* atau tidak.

# %%
UC[(UC['Type']=='Other')].Price.describe()
# Out:
# count        25.000000
# mean      46320.000000
# std      102417.434225
# min           0.000000
# 25%           0.000000
# 50%        2000.000000
# 75%       30000.000000
# max      375000.000000
# Name: Price, dtype: float64

# %% [markdown]
# Dari analisis ini kita dapat
# - Nilai `**Other**' memiliki rata-rata 46320
# - Terdapat 25 baris yang memiliki value other di kolom `Type`
# - Standart Deviasi dari `Type` terhadap Price adalah 102417

# %% [markdown]
# ##### 3. Memahami data **`Make`**

# %%
Value_Make = (UC[UC['Make']=='Other'])
print("Jumlah Mobil yang memiliki Make Other :",len(Value_Make))
# Out:
# Jumlah Mobil yang memiliki Make Other : 10

# %%
UC[(UC['Make']=='Other')].Price.describe()
# Out:
# count        10.000000
# mean      58350.000000
# std      117361.277449
# min           0.000000
# 25%           0.000000
# 50%        1000.000000
# 75%       20875.000000
# max      330000.000000
# Name: Price, dtype: float64

# %% [markdown]
# Dari analisis ini kita dapat
# - Nilai `**Other**' memiliki rata-rata 58350, dengan standart deviasi 117361.
# - Terdapat 10 kolom dengan value `Other` yang nantinya akan kita take out.

# %% [markdown]
# ##### 4. Memahami data **`Mileage`**

# %%
# Menghitung Q1 dan Q3
Q1 = UC['Mileage'].quantile(0.25)
Q3 = UC['Mileage'].quantile(0.75)
IQR = Q3 - Q1

# Menentukan batas bawah dan batas atas
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Mencari indeks outlier
outlier_indices = UC[(UC['Mileage'] < lower_bound) | (UC['Mileage'] > upper_bound)].index

# Menampilkan hasil
print(f'IQR: {IQR}')
print(f'limit_bawah: {lower_bound}')
print(f'limit_atas: {upper_bound}') 
print("Indeks outlier:", len(outlier_indices))
# Out:
# IQR: 158000.0
# limit_bawah: -199000.0
# limit_atas: 433000.0
# Indeks outlier: 175

# %% [markdown]
# ##### 5. Memahami data **`Price`**
#
# - Terdapat value "0" pada nilai `Price` nilai tersebut harus di pahami untuk mengetahu alasan mengapa value tersebut adalah "0" karena nilai tersebut terbilang banyak.

# %%
UC[UC['Price']==0]
# Out:
#               Type  Region     Make  Gear_Type       Origin    Options  Year  \
# 0          Corolla    Abha   Toyota     Manual        Saudi   Standard  2013
# 4               FJ  Riyadh   Toyota  Automatic        Saudi       Full  2020
# 9               LS   Aseer    Lexus  Automatic        Saudi       Full  1998
# 14           Hilux   Yanbu   Toyota  Automatic        Saudi       Full  2014
# 15    Land Cruiser   Aseer   Toyota     Manual  Gulf Arabic  Semi Full  1982
# ...            ...     ...      ...        ...          ...        ...   ...
# 5610      Town Car  Jeddah  Lincoln  Automatic      Unknown       Full  1999
# 5614      Victoria  Makkah     Ford  Automatic        Saudi   Standard  2010
# 5617         Yukon  Jubail      GMC  Automatic        Saudi  Semi Full  2006
# 5620        Altima  Jeddah   Nissan  Automatic        Saudi  Semi Full  2020
# 5623            ES  Jeddah    Lexus  Automatic      Unknown       Full  2017
#
# ...

# %%
sns.boxplot(data=UC, x='Price')
# Out:
# <Axes: xlabel='Price'>

# %%
print("Jumlah Mobil yang memiliki harga 0 sebanyak :",len(UC[UC['Price']==0]))
# Out:
# Jumlah Mobil yang memiliki harga 0 sebanyak : 1797

# %%
Value_price=len(UC[(UC['Price']==0)&(UC['Negotiable']==True)])
print('Total harga mobil 0 dan terbuka untuk negosiasi :',Value_price)
# Out:
# Total harga mobil 0 dan terbuka untuk negosiasi : 1796

# %%
# Menghitung Q1 dan Q3
Q1_Price = UC['Price'].quantile(0.25)
Q3_Price = UC['Price'].quantile(0.75)
IQR_Price = Q3_Price - Q1_Price

# Menentukan batas bawah dan batas atas
lower_bound_Price = Q1_Price - 1.5 * IQR_Price
upper_bound_Price = Q3_Price + 1.5 * IQR_Price

# Mencari indeks outlier
outlier_indices_Price = UC[(UC['Price'] < lower_bound_Price) | (UC['Price'] > upper_bound_Price)].index

# Menampilkan hasil
print(f'IQR: {IQR_Price}')
print(f'limit_bawah: {lower_bound_Price}')
print(f'limit_atas: {upper_bound_Price}') 
print("Indeks outlier:", len(outlier_indices_Price))
# Out:
# IQR: 72932.5
# limit_bawah: -109398.75
# limit_atas: 182331.25
# Indeks outlier: 261

# %% [markdown]
# #### **Kesimpulan Data Understanding.**
# 1. Pada kolom `Origin` Other sudah kita alihkan ka Unknown dan tidak perlu di take out, karena kolom origin hanya memiliki `2 penggolongan di Arab Saudi atau di luar Arab Saudi`.
# 2. Nilai `Other` pada kolom `Type` (25 baris) sebaiknya kita take out, karena tipe mobil dapat memberikan informasi yang baik dalam menentukan harga mobil tersebut.
# 3. Kolom `Make` yang merupakan nama perusahaan memiliki nilai `Other` sebanyak 10, nilai tersebut juga akan kita take out karena dalam dunia otomotif perusahaan pembuat mobil juga dapat menentukan harga karena ada beberapa perusahaan yang memeiliki kesan `Prestige`.
# 4. Kolom `Mileage` jika di lakukan pengecekan outlier terdapat 175 outlier, outlier tersebut akan kita take out karena memiliki distribusi nilai yang dapat membuat hasil analisis menjadi bias.
# 5. Dari pemaparan diatas harga mobil yang memiliki nilai `0` (1796 baris) terjadi karena harga mobil dapat di negosiasikan, artinya tidak ada kepastian harga pada mobil yang di jual, hal tersebut dapat memperngaruhi analisis karena nilia Price sebagai target akan memperngaruhi hasil dari Machine Learning.

# %% [markdown]
# #### **Take Out Error Value**
# ---

# %%
import pandas as pd

# 1. Drop value 0 di kolom 'Price'
UC_cleaned = UC[UC['Price'] != 0]

# 2. Drop outlier pada kolom 'Price' menggunakan metode IQR
Q1_Price = UC_cleaned['Price'].quantile(0.25)
Q3_Price = UC_cleaned['Price'].quantile(0.75)
IQR_Price = Q3_Price - Q1_Price

# Menentukan batas bawah dan batas atas untuk Price
lower_bound_Price = Q1_Price - 1.5 * IQR_Price
upper_bound_Price = Q3_Price + 1.5 * IQR_Price

# Menampilkan hasil IQR
print(f'IQR Price: {IQR_Price}')
print(f'Limit Bawah Price: {lower_bound_Price}')
print(f'Limit Atas Price: {upper_bound_Price}')

# Filter outlier pada Price
UC_cleaned = UC_cleaned[(UC_cleaned['Price'] >= lower_bound_Price) & (UC_cleaned['Price'] <= upper_bound_Price)]

# 3. Drop value 'Other' di kolom 'Type'
UC_cleaned = UC_cleaned[UC_cleaned['Type'] != 'Other']

# 4. Drop value 'Other' di kolom 'Make'
UC_cleaned = UC_cleaned[UC_cleaned['Make'] != 'Other']

# 5. Drop outlier pada kolom 'Mileage' menggunakan metode IQR
Q1_Mileage = UC_cleaned['Mileage'].quantile(0.25)
Q3_Mileage = UC_cleaned['Mileage'].quantile(0.75)
IQR_Mileage = Q3_Mileage - Q1_Mileage

# Menentukan batas bawah dan batas atas untuk Mileage (menggunakan 3 * IQR)
lower_bound_Mileage = Q1_Mileage - 1.5  * IQR_Mileage
upper_bound_Mileage = Q3_Mileage + 1.5 * IQR_Mileage

UC_cleaned = UC_cleaned[(UC_cleaned['Mileage'] >= lower_bound_Mileage) & (UC_cleaned['Mileage'] <= upper_bound_Mileage)]

# 6. Drop baris yang duplikat
UC_cleaned = UC_cleaned.drop_duplicates()

# 7. Menghitung jumlah dan persentase data yang dihapus
rows_dropped = len(UC) - len(UC_cleaned)
percentage_dropped = (rows_dropped / len(UC)) * 100

print(f"Jumlah baris yang di-drop: {rows_dropped}")
print(f"Persentase data yang di-drop: {percentage_dropped:.2f}%")
# Out:
# IQR Price: 59000.0
# Limit Bawah Price: -53500.0
# Limit Atas Price: 182500.0
# Jumlah baris yang di-drop: 2192
# Persentase data yang di-drop: 38.98%

# %% [markdown]
# terdapat 2192 baris yang di take out atau 38.98% dari data yang kita miliki di take out atau didrop

# %% [markdown]
# #### **Rechek Data**
# ---

# %%
UC_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3432 entries, 1 to 5622
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         3432 non-null   object
#  1   Region       3432 non-null   object
#  2   Make         3432 non-null   object
#  3   Gear_Type    3432 non-null   object
#  4   Origin       3432 non-null   object
#  5   Options      3432 non-null   object
#  6   Year         3432 non-null   int64
#  7   Engine_Size  3432 non-null   float64
#  8   Mileage      3432 non-null   int64
#  9   Negotiable   3432 non-null   bool
#  10  Price        3432 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 298.3+ KB

# %%
# Check unique in each variable
pd.set_option('display.max_colwidth', None)

item = []
for i in UC_cleaned.columns :
    item.append([i, UC_cleaned[i].nunique(), UC_cleaned[i].unique()])

table_unique = pd.DataFrame(columns=['Column Name', 'Number of Unique', 'Unique Sample'],
                            data = item)
table_unique
# Out:
#     Column Name  Number of Unique  \
# 0          Type               303
# 1        Region                27
# 2          Make                53
# 3     Gear_Type                 2
# 4        Origin                 3
# 5       Options                 3
# 6          Year                39
# 7   Engine_Size                61
# 8       Mileage              1214
# 9    Negotiable                 1
# 10        Price               347
#
# ...

# %% [markdown]
# Jumlah kolom yang di miliki saat ini adalah 3432 yang sebelumnya terdapat 5624, pada analisi ini kita akan melakukan drop kolom `Negotiable`. bisa di lihat pada unique value data yang sudah di bersihkan, kolom `Negotiable` hanya berisi *False* hal tersebut terjadi karena Value *True* di kolom tersebut sudah di kita drop sebelumnya. maka kita akan melakukan drop pada kolom **`Negotiable`**.

# %%
UC_cleaned.drop(['Negotiable'], axis=1, inplace=True)
UC_cleaned.head(1)
# Out:
#     Type  Region Make  Gear_Type Origin Options  Year  Engine_Size  Mileage  \
# 1  Yukon  Riyadh  GMC  Automatic  Saudi    Full  2014          8.0    80000
#
#     Price
# 1  120000

# %%
UC_cleaned.describe(include='all')
# Out:
#           Type  Region    Make  Gear_Type Origin   Options         Year  \
# count     3432    3432    3432       3432   3432      3432  3432.000000
# unique     303      27      53          2      3         3          NaN
# top     Accent  Riyadh  Toyota  Automatic  Saudi  Standard          NaN
# freq       146    1444     787       3082   2645      1266          NaN
# mean       NaN     NaN     NaN        NaN    NaN       NaN  2014.935315
# std        NaN     NaN     NaN        NaN    NaN       NaN     4.771419
# min        NaN     NaN     NaN        NaN    NaN       NaN  1964.000000
# 25%        NaN     NaN     NaN        NaN    NaN       NaN  2014.000000
# 50%        NaN     NaN     NaN        NaN    NaN       NaN  2016.000000
# 75%        NaN     NaN     NaN        NaN    NaN       NaN  2018.000000
# max        NaN     NaN     NaN        NaN    NaN       NaN  2021.000000
#
#         Engine_Size        Mileage          Price
# count   3432.000000    3432.000000    3432.000000
# ...

# %%
plt.figure(figsize=(6,6))
sns.distplot(UC_cleaned['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# Durasi perjalanan pemegang polis yang membeli produk Annual Silver Plan (terkecil ke terbesar)
UC_cleaned.sort_values(['Price'], ascending = True)
# Out:
#               Type  Region      Make  Gear_Type   Origin    Options  Year  \
# 3131         Yukon  Jubail       GMC  Automatic    Saudi       Full  2019
# 3992           G80  Riyadh   Genesis  Automatic  Unknown  Semi Full  2018
# 4399         Yaris  Riyadh    Toyota  Automatic    Saudi   Standard  2018
# 5128           Rio    Arar       Kia  Automatic    Saudi   Standard  2019
# 3474         Yaris  Najran    Toyota  Automatic    Saudi   Standard  2019
# ...            ...     ...       ...        ...      ...        ...   ...
# 2852    Expedition  Riyadh      Ford  Automatic    Saudi       Full  2020
# 3155            XJ  Jeddah    Jaguar  Automatic    Saudi       Full  2015
# 819              C  Dammam  Mercedes  Automatic    Saudi       Full  2018
# 2522      Wrangler  Riyadh      Jeep  Automatic    Saudi       Full  2019
# 2605  Land Cruiser  Dammam    Toyota  Automatic    Saudi       Full  2017
#
#       Engine_Size  Mileage   Price
# 3131          5.3    50000       1
# ...

# %%
len(UC_cleaned[UC_cleaned['Price']>=1000])
# Out:
# 3425

# %% [markdown]
# **Price :**
# 1. Visualisasi plot pada distribusi harga mobil bekas di arab saudi yang sudah di data cleasing masih menunjukan condong ke arah kanan atau bisa di sebut "Right-Skewed Distribution". hal tersbeut menunjukan skewness positif pada fitur Price (Target). selain itu harga mobil bekas di arab saudi terbilang rendah dan sedikit yang memiliki harga tinggi.
# 2. Terdapat Outlier lain pada nilai price, terdapat nilai 1 pada price yang akan kita take out atau drop, karena nilai tersebut dapat di sebut anomali.

# %%
# Drop value 1 di kolom 'price'
UC_cleaned = UC_cleaned[UC_cleaned['Price'] != 1]

# %% [markdown]
# ## **EDA**
# ---

# %% [markdown]
# ### Visualisasi data berdasarkan 10 teratas
# ---

# %% [markdown]
# #### 1. 10 mobil dengan rata-rata harga tertinggi

# %%
# 1. Kelompokkan data berdasarkan 'Make' (merek mobil) dan hitung rata-rata 'Price'
grouped_by_make = UC.groupby('Make')['Price'].mean()

# 2. Urutkan hasilnya secara descending (menurun) berdasarkan rata-rata harga
sorted_by_price = grouped_by_make.sort_values(ascending=False)

# 3. Ambil 10 data teratas
top_10_makes = sorted_by_price.head(10)

# 4. Tampilkan hasilnya
print(top_10_makes)

# Visualisasinya
plt.figure(figsize=(10, 6))  # Atur ukuran figure
plt.bar(top_10_makes.index, top_10_makes.values)
plt.title('10 Merek Mobil dengan Rata-rata Harga Tertinggi')
plt.xlabel('Merek Mobil')
plt.ylabel('Rata-rata Harga')
plt.xticks(rotation=45, ha='right')  # Rotasi label sumbu x agar tidak bertumpuk
plt.tight_layout()  # Menyesuaikan layout agar label tidak terpotong
plt.show()
# Out:
# Make
# Rolls-Royce     476666.666667
# Bentley         388750.000000
# Aston Martin    290000.000000
# Ferrari         280000.000000
# Maserati        211666.666667
# Land Rover      186626.582278
# Mercedes        125411.504425
# Jaguar          116666.666667
# Lexus           116461.711712
# Porsche         114227.272727
# Name: Price, dtype: float64

# %% [markdown]
# #### 2. 10 mobil dengan merek terbanyak yang di jual

# %%
# 1. Kelompokan data berdasarkan Make (ambil 10 teratas)
top_10_Cars= UC['Make'].value_counts().head(10)
print (top_10_Cars)

# Visualisasinya
plt.figure(figsize=(10, 6))
top_10_Cars.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Top 10 Car Makes', fontsize=14)
plt.xlabel('Car Make', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)  
plt.show()
# Out:
# Make
# Toyota       1431
# Hyundai       670
# Ford          530
# Chevrolet     458
# Nissan        387
# GMC           282
# Kia           251
# Mercedes      226
# Lexus         222
# Mazda         129
# Name: count, dtype: int64

# %% [markdown]
# - Mobil yang memiliki rata-rata harga tertinggi umumnya di isi mobil "Mewah" hal tersebut wajar karena mobil tersebut memiliki harg ayang tinggi di pasaran
# - Mobil dengan merek mobil bekas terbanyak terdapat pada Toyota

# %% [markdown]
# ### Box Plot dan Plot Distribusi

# %%
# Set ukuran figure dan layout 3 baris × 2 kolom
fig, axes = plt.subplots(3, 2, figsize=(14, 15))

# Boxplot Mileage
sns.boxplot(x=UC_cleaned['Mileage'], ax=axes[0, 0], color='green')
axes[0, 0].set_title('Boxplot Mileage')

# Histogram Mileage dengan KDE
sns.histplot(UC_cleaned['Mileage'], kde=True, ax=axes[0, 1], color='green', bins=30)
axes[0, 1].set_title('Distribusi Mileage')

# Boxplot Price
sns.boxplot(x=UC_cleaned['Price'], ax=axes[1, 0], color='blue')
axes[1, 0].set_title('Boxplot Price')

# Histogram Price dengan KDE
sns.histplot(UC_cleaned['Price'], kde=True, ax=axes[1, 1], color='blue', bins=30)
axes[1, 1].set_title('Distribusi Price')

# Boxplot Engine Size
sns.boxplot(x=UC_cleaned['Engine_Size'], ax=axes[2, 0], color='purple')
axes[2, 0].set_title('Boxplot Engine Size')

# Histogram Year dengan KDE
sns.histplot(UC_cleaned['Year'], kde=True, ax=axes[2, 1], color='orange', bins=30)
axes[2, 1].set_title('Distribusi Year')

# Menyempurnakan layout
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1. Boxplot dan Distribusi Mileage
# - Boxplot Mileage (Kiri Atas, Hijau):
#
#     - Rentang interkuartil (IQR) cukup luas, menunjukkan variasi yang besar dalam jarak tempuh kendaraan.
#     - Ada outlier di sisi kanan (nilai mileage yang sangat tinggi di atas 350.000). Meskipun begitu nilai tersebut masih terbilang wajar pada kilometer sebuah mobill (terlebih terdapat mobil di tahun 1963).
# - Distribusi Mileage (Kanan Atas, Hijau):
#
#     - Distribusi kanan miring (positively skewed), yang berarti mayoritas kendaraan memiliki mileage rendah hingga sedang, tetapi ada beberapa kendaraan dengan mileage yang sangat tinggi.
#     - Puncak distribusi berada di sekitar 50.000 - 100.000 miles, yang kemungkinan besar merupakan mileage umum untuk mobil bekas.
# #### 2. Boxplot dan Distribusi Price
# - Boxplot Price (Kiri Tengah, Biru):
#
#     - Rentang harga cukup besar, dengan beberapa outlier di sisi kanan (harga mobil yang sangat mahal di atas 150.000).
#     - Harga median berada di sekitar 50.000 - 75.000.
# - Distribusi Price (Kanan Tengah, Biru):
#
#     - Distribusi kanan miring, menunjukkan lebih banyak mobil dengan harga rendah hingga menengah.
#     - Peak harga berada di sekitar 25.000 - 50.000, kemungkinan besar ini adalah harga yang paling umum untuk mobil dalam dataset.
#     - Beberapa kendaraan memiliki harga di atas 150.000, yang bisa jadi adalah mobil mewah atau edisi khusus.
# #### 3. Boxplot dan Distribusi Engine Size
# - Boxplot Engine Size (Kiri Bawah, Ungu):
#
#     - Engine size sebagian besar berada di kisaran 1.0 - 5.0 liter, dengan beberapa outlier di atas 7.0 liter.
#     - Outlier ini kemungkinan besar adalah kendaraan performa tinggi atau kendaraan besar seperti truk/SUV.
# - Distribusi Engine Size (Tidak terlihat dalam plot ini, namun dapat dianalisis dari boxplot):
#
#     - Sebagian besar kendaraan memiliki mesin berukuran antara 1.5 - 3.5 liter, sesuai dengan mobil biasa seperti sedan dan hatchback.
#     - Mesin di atas 5.0 liter cukup jarang, mungkin mewakili kendaraan performa tinggi atau SUV besar.
# #### 4. Distribusi Year
# - Distribusi Year (Kanan Bawah, Kuning):
#     - Distribusi sangat condong ke kanan, artinya lebih banyak kendaraan dari tahun terbaru dibandingkan kendaraan lama.
#     - Sebagian besar mobil dalam dataset berasal dari tahun 2000-an hingga 2020-an, dengan puncak sekitar 2015 - 2020.
#     - Hampir tidak ada kendaraan dari tahun 1970-an ke bawah, yang berarti dataset lebih berfokus pada mobil yang relatif modern.
#
# #### 5. Kesimpulan Umum
# - Mileage dan Price memiliki banyak outlier, yang menunjukkan adanya kendaraan dengan jarak tempuh sangat tinggi dan harga yang sangat tinggi.
# - Distribusi harga dan mileage cenderung miring ke kanan, yang berarti ada lebih banyak mobil dalam kisaran rendah-menengah.
# - Engine size sebagian besar kecil hingga sedang, dengan beberapa kendaraan outlier yang memiliki mesin besar.
# - Mobil dalam dataset sebagian besar dari tahun 2000-an ke atas, menunjukkan dataset ini lebih fokus pada mobil modern.

# %% [markdown]
# ### **Correlation Matrix**
#
# Mencari hubungan antar korelasi antar masing-masing fitur numerikal untuk mengetahui hubungan antar fitur. metode yang di gunakan adalah person karena untuk mencari nilai numerikal tanpa memberikan urutan pada masing-masing nilai

# %%
# Memilih hanya kolom numerik
numeric_columns = UC_cleaned.select_dtypes(include=['number'])

# Menghitung korelasi menggunakan metode Pearson
correlation_matrix = numeric_columns.corr(method='pearson')

# Membuat heatmap dengan Seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Menampilkan plot
plt.title("Correlation Matrix (Pearson Method)")
plt.show()

# %% [markdown]
# Berikut adalah analisis singkat dari Correlation Matrix (Pearson Method):
#
# 1. Year vs Price (0.34) → Korelasi positif lemah
#
#     - Semakin baru tahun kendaraan, semakin tinggi harganya.
# 2. Year vs Engine Size (-0.30) → Korelasi negatif lemah
#
#     - Kendaraan lebih baru cenderung memiliki mesin lebih kecil (efisiensi meningkat).
# 3. Year vs Mileage (-0.34) → Korelasi negatif lemah
#
#     - Kendaraan lebih baru biasanya memiliki jarak tempuh lebih rendah.
# 4. Engine Size vs Price (0.32) → Korelasi positif lemah
#
#     - Kendaraan dengan mesin lebih besar cenderung memiliki harga lebih tinggi.
# 5. Engine Size vs Mileage (0.21) → Korelasi positif sangat lemah
#
#     - Mesin yang lebih besar cenderung ada pada kendaraan dengan jarak tempuh lebih tinggi.
# 6. Mileage vs Price (-0.23) → Korelasi negatif lemah
#
#     - Kendaraan dengan jarak tempuh lebih tinggi cenderung memiliki harga lebih rendah.
# **Kesimpulan:**
#
# - Tidak ada korelasi yang sangat kuat.
# - Harga kendaraan dipengaruhi oleh tahun produksi, ukuran mesin, dan jarak tempuh, tetapi dalam hubungan yang relatif lemah.
# - Kendaraan lebih baru cenderung lebih mahal, lebih efisien, dan memiliki jarak tempuh lebih rendah.
#
# ---

# %% [markdown]
# ## **Featur Selection**
#
# Kita memilih fitur yang akan digunakan untuk, dalam tahap ini akan ada fitur yang di pertahankan dan akan di drop untuk memudahkan dalam melakukan analsisi dengan penjelasan berikut :
# - Terdapat 10 Fitur yaitu `Type`,	`Region`,	`Make`,	`Gear_Type`,	`Origin`,	`Options`,	`Year`,	`Engine_Size`,	`Mileage`,	`Price`
# - Terdapat fitur yang akan di drop atau di hilangkan karena di rasa tidak mempengaruhi hasil permodelan dengan penjelasan berikut :
#     - **Region** : Isi dari kolom region adalah informasi mengenai lokasi mobil tersebut di jual, informasi tersebut tidak dapat kita jadikan acuan karena dimanapun lokasi mobil tersebut di jual pembeli tetap akan mencari lokasi terdekat dengan harga paling murah.
#     - **Negotiable** : kolom tersebut sudah di drop sebelum dilakukan Featur Selection karena valu hanya berisi False atau tidak dapat di negosiasikan.
#     - **Price** : Nilai Price juga akan di drop pada karena merupakan target yang dianalisis pada model Machine Learning.
# - Fitur yang di gunakan adalah `Type`,	`Make`,	`Gear_Type`,	`Origin`,	`Options`,	`Year`,	`Engine_Size`,	`Mileage`. fitur tersebut digunakan karena :
#     - `Type`        : Fitur yang Tipe mobil sangan menentukan harga mobil karena setiap merek mobil memiliki tipe dan series masing-masing
#     - `Make`        : Negara tempat mobil tersebut menunjukan dimana mobil tersebut di buat, lokasi menentukan harga karena menentukan jalur distribusi dan lain sebagainya.
#     - `Gear_Type`   : Tedapat 2 jenis tipe gear, di indonesia sendiri umumnya mobil dengan gera Autometic memiliki harga yang lebih mahal dibanding dengan mobil Manual.
#     - `Origin`      : Lokasi dimana mobil tersebut di jual umumnya menentukan sistem distibusi dan harga.
#     - `Options`     : Opsi fitur mobil sangat menentukan harga karena berpengaruh pada apa saja yang dapat di berikan mobil tersebut pada pemiliknya
#     - `Year`        : semakin baru tahun pembuatan makin mahal harga mobilnya dan begitu sebaliknya (Kecuali mobil anti/koleksi)
#     - `Engine_Size` : Ukuran mesin menentukan performa mobil maka umumnya akan mempengaruhi harga mobil.
#     - `Mileage`     : Semakin tinggi kilometer penggunaan mobil tersebut harga mobil bisa semakin jatuh.
#
# ---

# %%
# Memilih fitur yang digunakan
selected_features = ['Type', 'Make', 'Gear_Type', 'Origin', 'Options', 'Year', 'Engine_Size', 'Mileage','Price']
# Membuat dataset baru hanya dengan fitur yang dipilih
UC_selected = UC_cleaned[selected_features]
# Menampilkan 5 data pertama untuk verifikasi
UC_selected.head(5)
# Out:
#         Type     Make  Gear_Type Origin    Options  Year  Engine_Size  \
# 1      Yukon      GMC  Automatic  Saudi       Full  2014          8.0
# 3     Optima      Kia  Automatic  Saudi  Semi Full  2015          2.4
# 5        CX3    Mazda  Automatic  Saudi  Semi Full  2019          2.0
# 6  Cayenne S  Porsche  Automatic  Saudi       Full  2012          4.8
# 7     Sonata  Hyundai  Automatic  Saudi       Full  2016          2.4
#
#    Mileage   Price
# 1    80000  120000
# 3   220000   42000
# 5    25000   58000
# 6   189000   85000
# 7      155   48000

# %%
UC_selected.nunique()
# Out:
# Type            303
# Make             53
# Gear_Type         2
# Origin            3
# Options           3
# Year             39
# Engine_Size      61
# Mileage        1214
# Price           346
# dtype: int64

# %% [markdown]
# ---
# ## **Featur Enginering**
#
# Berikut adalah beberapa Feature engineering yang akan dilakukan :
#
# **1) Encoding**
#
# Setelah memeriksa seluruh dataset dan memastikan tipe data di setiap kolom sudah yang sesuai, diputuskan untuk memproses data kategorikal dengan encoding agar memudahkan analisis dan pemodelan, hal tersebut dilakukan karena komputer tidak dapat di perintah dengan objek melainkan dengan nilai numerikal sebagai kodenya. Data numerikal tidak akan diubah.
#
# Metode encoding yang akan digunakan adalah:
#
# 1. One Hot Encoding : `Gear_Type`, `Origin`, dan `Options`. ketiga variabel tersebut hanya memiliki sedikit data unik sehingga dapat menggunakan preprocessing One Hot Encoding. Pada fitur tersebut dilakukan Drop first sebab jika tidak dilakukan dapat menyebabkan overfitting terutama pada model Logistic regression.
# 2. Binary Encoding  : `Type`& `Make`. kedua variabel tersebut memiliki banyak data unik.
# 3. standard scaler  : `Year`, `Engine_Size`,& `Mileage`. ketiga variabel tersebut sudah berisi numerikal sehingga menggunakan standard scaler untuk menyamaratakan seluruh fitur.

# %%
# Mengubah fitur kategorikal menjadi numerikal

transformer = ColumnTransformer([
    ('One Hot', OneHotEncoder(drop='first'), [ 'Gear_Type', 'Origin', 'Options']),
    ('Binary', ce.BinaryEncoder(), ['Type','Make'])
], remainder='passthrough')

# %% [markdown]
# ##### **Data Spliting**

# %%
# Memisahkan data independen variabel dengan target
X = UC_selected.drop(['Price'], axis=1)
y = UC_selected['Price']

# %% [markdown]
# #### **Train and Test Splitting**

# %%
# Splitting data training dan test dengan proporsi 70:30
X_train, X_test, y_train, y_test= train_test_split(
    X,
    y,  
    test_size=0.3,
    random_state=1)

# %%
 #Harga terkecil dan terbesar pada y_train
min_y_train = np.min(y_train)
max_y_train = np.max(y_train)

# Harga terkecil dan terbesar pada y_test
min_y_test = np.min(y_test)
max_y_test = np.max(y_test)

print(f"y_train: Min = {min_y_train}, Max = {max_y_train}")
print(f"y_test: Min = {min_y_test}, Max = {max_y_test}")
# Out:
# y_train: Min = 850, Max = 182000
# y_test: Min = 500, Max = 180000

# %% [markdown]
# ---
# ### **Analytics (Modelling and Evaluation)**
#
# **Model yang digunakan**
#
# Untuk membuat model **Machine Learning** untuk prediksi **harga mobil bekas** di **Arab Saudi**, kita harus mempertimbangkan model yang mampu menangani **data regresi**, menangani **outlier**, dan memberikan hasil yang **stabil serta akurat**.
#
# ---
#
# Berikut adalah **model yang yang dipilih dan alasannya**:
#
# 1. **RandomForest Regressor (rf) ✅**
#    - Mampu menangani **non-linearitas** dalam data.
#    - Tahan terhadap **outlier** dan fitur yang tidak terlalu penting.
#    - Tidak terlalu sensitif terhadap skala data.
#
# 2. **Gradient Boosting Regressor (gb) ✅**
#    - Performa tinggi dalam banyak kasus regresi.
#    - Dapat menangani **data dengan pola kompleks**.
#    - Cenderung lebih akurat dibandingkan **Decision Tree** tunggal.
#
# 3. **XGBoost Regressor (xgb) ✅**
#    - Versi lebih cepat dan lebih efisien dari Gradient Boosting.
#    - Mampu menangani **missing values** secara otomatis.
#    - Banyak digunakan dalam kompetisi **data science** karena performanya yang unggul.
#
# 4. **Decision Tree Regressor (dt) ✅**
#    - Mudah diinterpretasikan dan cepat dalam prediksi.
#    - Cocok untuk menangani **data yang memiliki hubungan non-linear**.
#    - Bisa menjadi baseline sebelum menggunakan **ensemble models**.
#
# 5. **Linear Regression (lr)**
#    - Implementasi mudah dan sederhana
#    - Cocok untuk data yang memiliki linearitas
#    - Funsgi model yang lebih efisien
#    - Kombinasi **Lasso dan Ridge Regression**, cocok jika data memiliki **banyak fitur**.
#    - Dapat menangani **multikolinearitas** lebih baik dibandingkan regresi linier biasa.
#    - Cocok untuk dataset dengan fitur yang memiliki korelasi tinggi.
#
# 6. **AdaBoost Regressor (ada) ✅**
#    - Menggunakan pendekatan **boosting** untuk meningkatkan performa model dasar.
#    - Bagus dalam **meningkatkan akurasi model yang lemah** seperti Decision Tree.
#    - Bisa digunakan untuk mengatasi **outlier**, meskipun tidak sekuat Random Forest.
#
# 7. **K-Nearest Neighbors Regressor (knn) ✅**
#    - Efisien untuk dataset **tidak terlalu besar** karena menghitung jarak antar data.
#    - Tidak dapat menangani **cocok karena data yang dimiliki relatif kecil**
#    - Sensitif terhadap **skala data**, sehingga perlu normalisasi yang hati-hati.
# ---
#
# ### **Kesimpulan**
# Jika ingin membangun model **harga mobil bekas di Arab Saudi**, **7 model terbaik yang direkomendasikan adalah:**
# - **RandomForest Regressor (rf)**
# - **Gradient Boosting Regressor (gb)**
# - **XGBoost Regressor (xgb)**
# - **Decision Tree Regressor (dt)**
# - **Linear Regression (lr)**
# - **K-Nearest Neighbors Regressor (knn)**
# - **AdaBoost Regressor (ada)**
#
# Model-model ini memberikan keseimbangan antara **akurasi, interpretabilitas, dan ketahanan terhadap outlier**, serta cocok untuk **data regresi harga mobil bekas** yang cenderung memiliki pola non-linear. 🚗💰🚀

# %% [markdown]
# ---

# %% [markdown]
# **Matrix Evaluation**
#
# Ketika menentukan harga beli mobil yang sesuai menggunakan model regresi, pemilihan metrik evaluasi sangat penting agar hasil prediksi akurat dan stabil. **Tiga metrik utama** yang sering digunakan dalam regresi adalah **RMSE (Root Mean Squared Error) dan MAE (Mean Absolute Error). Berikut adalah alasan mengapa masing-masing metrik ini relevan untuk menilai model yang memprediksi harga mobil bekas:
#
# ---
#
# **1. RMSE (Root Mean Squared Error) – Mengutamakan Error Besar**
#
# **Alasan menggunakan RMSE:**
# ✅ **Sensitif terhadap outlier**: RMSE mengkuadratkan error sebelum mengambil rata-rata, sehingga memberikan **penalti lebih besar untuk kesalahan besar**. Ini berguna karena dalam harga mobil, terdapat variasi harga tinggi (contoh: mobil mewah dan mobil ekonomi).
# ✅ **Baik untuk model dengan harga tinggi**: Jika kita ingin menghindari kesalahan besar dalam prediksi harga mobil mahal, RMSE adalah metrik yang tepat karena error besar akan sangat berpengaruh pada hasil akhir.
# ✅ **Menjaga stabilitas harga jual**: Dengan menggunakan RMSE, kita dapat meminimalkan kesalahan besar dalam harga jual, sehingga mengurangi risiko menetapkan harga terlalu rendah atau terlalu tinggi.
#
# 📌 **Kelemahan**: Karena lebih sensitif terhadap outlier, RMSE bisa lebih tinggi jika terdapat harga ekstrem dalam dataset.
#
# ---
#
#  **2. MAE (Mean Absolute Error) – Memastikan Error Rata-rata**
#
# **Alasan menggunakan MAE:**
# ✅ **Lebih mudah diinterpretasikan**: MAE menunjukkan rata-rata kesalahan dalam unit yang sama dengan target (misalnya, jika MAE = 5,000, berarti prediksi harga mobil rata-rata meleset sebesar $5,000).
# ✅ **Tidak terlalu dipengaruhi oleh outlier**: Berbeda dengan RMSE, MAE tidak mengkuadratkan error, sehingga kesalahan besar dan kecil memiliki dampak yang sama.
# ✅ **Cocok untuk rentang harga yang luas**: Dalam pasar mobil bekas, harga bisa bervariasi dari $5,000 hingga $100,000. MAE memberikan gambaran yang lebih realistis tentang rata-rata kesalahan prediksi.
#
# 📌 **Kelemahan**: Tidak memberi penalti lebih besar pada error besar, sehingga bisa kurang efektif dalam mendeteksi outlier dibandingkan RMSE.
#
# ---
#
#  **Kesimpulan**
# Untuk menentukan harga beli mobil yang sesuai, kita menggunakan **kombinasi dari ketiga metrik ini**:
# 📌 **RMSE** → Menghindari kesalahan besar dalam harga jual.
# 📌 **MAE** → Memberikan gambaran rata-rata kesalahan yang mudah dipahami.
#
# 🔹 **Jika ingin memprioritaskan kestabilan harga jual** → Gunakan **RMSE**.
# 🔹 **Jika ingin meminimalkan kesalahan absolut** → Gunakan **MAE**.
#
# Idealnya, ketiga metrik ini digunakan bersama untuk mendapatkan pemahaman yang lebih komprehensif tentang performa model dalam menentukan harga mobil yang sesuai. 🚗💰

# %%
# Define Models Algoritm
lr = LinearRegression()
knn = KNeighborsRegressor()
dt = DecisionTreeRegressor(random_state=1)
rf = RandomForestRegressor(random_state=1)
ada = AdaBoostRegressor(random_state=1)
gb = GradientBoostingRegressor(random_state=1)
xgb = XGBRegressor(random_state=1)

# Scale models to logaricmic and transform to original (normalize)
log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(dt, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_ada = TransformedTargetRegressor(ada, func=np.log, inverse_func=np.exp)
log_gb = TransformedTargetRegressor(gb, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)

# Scaling data
scaler = StandardScaler()

# Models list
models = [log_lr, log_knn, log_dt, log_rf, log_ada, log_gb, log_xgb]


score_rmse = []
nilai_mean_rmse = []
nilai_std_rmse = []

score_mae = []
nilai_mean_mae = []
nilai_std_mae = []

# Mencari algoritma terbaik berdasarkan tiap metrics
for i in models:
    
    crossval = KFold(n_splits=5, shuffle=True, random_state=1)

    estimator = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', i)
    ])

    # RMSE
    model_cv_rmse = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_root_mean_squared_error', 
        error_score='raise'
        )

    print(model_cv_rmse, i)

    score_rmse.append(model_cv_rmse)
    nilai_mean_rmse.append(model_cv_rmse.mean())
    nilai_std_rmse.append(model_cv_rmse.std())

    # MAE
    model_cv_mae = cross_val_score(
        estimator, 
        X_train, 
        y_train, 
        cv=crossval, 
        scoring='neg_mean_absolute_error', 
        error_score='raise'
        )

    print(model_cv_mae, i)

    score_mae.append(model_cv_mae)
    nilai_mean_mae.append(model_cv_mae.mean())
    nilai_std_mae.append(model_cv_mae.std())
# Out:
# [-31101.38276882 -32190.09586689 -28750.05076942 -29353.07933988
#  -27592.72308257] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-21022.37438887 -21024.13608419 -20229.79537037 -19639.08396206
#  -19610.29776111] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=LinearRegression())
# [-28926.88389492 -27978.28853259 -26958.27435518 -28677.98805865
#  -27569.78717483] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KNeighborsRegressor())
# [-19486.73157549 -19353.36013256 -18469.89034663 -19019.28823301
#  -18816.21953053] TransformedTargetRegressor(func=<ufunc 'log'>, inverse_func=<ufunc 'exp'>,
#                            regressor=KNeighborsRegressor())
# [-34719.02874436 -31106.56729489 -31035.03799643 -27839.55189556
# ...

# %%
model_names = ['Linear Regression', 'KNN Regressor', 'DecisionTree Regressor', 'RandomForest Regressor', 'AdaBoost Regressor', 'Gradient Boosting Regressor', 'XGBoost Regressor']

# Evaluasi hasil dari 5 kandidat algoritma yang digunakan
pd.DataFrame({
    'Model': model_names,
    'Mean_RMSE': nilai_mean_rmse,
    'Std_RMSE': nilai_std_rmse,
    'Mean_MAE': nilai_mean_mae,
    'Std_MAE': nilai_std_mae,

})
# Out:
#                          Model     Mean_RMSE     Std_RMSE      Mean_MAE  \
# 0            Linear Regression -29797.466366  1648.048914 -20305.137513
# 1                KNN Regressor -28022.244403   719.312766 -19029.097964
# 2       DecisionTree Regressor -30410.942977  2660.327406 -18969.333444
# 3       RandomForest Regressor -25305.338298  2198.727875 -15592.228040
# 4           AdaBoost Regressor -41109.553864  3830.088819 -29051.510997
# 5  Gradient Boosting Regressor -25912.201076  1521.484416 -16799.619900
# 6            XGBoost Regressor -27288.460368  1581.411251 -16669.532967
#
#        Std_MAE
# 0   626.656801
# 1   366.797245
# 2  1255.580285
# 3  1131.037998
# 4  2935.346239
# 5   782.595013
# 6  1169.201099

# %% [markdown]
# **Memilih Model Terbaik**
# 1. XGBoost Regressor
#     - Memiliki kesalahan rata-rata terkecil dalam hal MAE dan RMSE, yang menunjukkan bahwa model ini paling akurat dalam memprediksi nilai target.
#     - XGBoost dikenal karena kemampuannya dalam menangani dataset besar dan mengoptimalkan kinerja dengan menggunakan boosting.
# 2. Gradient Boosting Regressor
#      - Memiliki performa yang stabil dengan nilai RMSE & MAE yang rendah.
#      - Gradient Boosting adalah metode yang sangat efektif untuk meningkatkan akurasi prediksi dan cocok untuk berbagai jenis data.
# 3. Random Forest Regression
#     - Memiliki kesalahan rata-rata terkecil dalam hal MAE dan RMSE, sama dengan XGBoost model tersebut juga akurat dalam memprediksi nilai target.
#     - Random Forest adalah metode yang dapat membantu kita jika memiliki fitur yang tidak memiliki korelasi pada data.

# %%
# Benchmark 3 model terbaik
models = {
    'XGB': XGBRegressor(random_state=1),
    'RandomForest': RandomForestRegressor(random_state=1),
    'Gradient Boosting': GradientBoostingRegressor(random_state=1)
}

score_rmse = []
score_mae = []

# Prediksi pada test set
for i in models:

    model = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', models[i])
        ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'RMSE': score_rmse, 'MAE': score_mae}, index=models.keys())
score_before_tuning
# Out:
#                            RMSE           MAE
# XGB                20522.370712  13744.589779
# RandomForest       21524.509361  13715.176825
# Gradient Boosting  21623.901751  14842.054872

# %% [markdown]
# **XGB Boost Regresion** memiliki secara akumulatif lebih baik pada nilai RMSE dan MAE yang sedikit lebih rendah dari model lainnya, maka dari itu best model yang dapat di gunakan pada **XGB Boost Regresion** karena memiliki nilai lebih rendah dari random forest atau gradient boosting

# %% [markdown]
# ### **Hyperparameter Tunning**
#
# Hyperparameter tuning yang akan di lakukan menggunakan model XG Boost Regresion adalah proses untuk mencari nilai optimal dari hyperparameter suatu model machine learning untuk memperbaiki performa model machine learning Ini dilakukan dengan mencoba berbagai nilai hyperparameter dan membandingkan hasil mereka dengan metrik performa seperti akurasi atau F1 score. Hyperparameter tunning dapat di lakukan dengan cara [Tuning XGBoost](https://xgboost.readthedocs.io/en/latest/parameter.html#general-parameters).

# %%
# Kedalaman pohon
max_depth = list(np.arange(1, 11))

# Learning rate
learning_rate = list(np.arange(1, 100)/100)

# Jumlah pohon
n_estimators = list(np.arange(100, 201))

# Jumlah baris tiap pohon (% dari total baris train set)
subsample = list(np.arange(2, 10)/10)

# Gamma (min_impurity_decrease)
gamma = list(np.arange(1, 11)) # Semakin besar nilainya, semakin konservatif/simpel modelnya

# Jumlah feature yang digunakan untuk tiap pohon (% dari total kolom train set)
colsample_bytree = list(np.arange(1, 10)/10)

# Alpha (regularization)
reg_alpha = list(np.logspace(-3, 1, 10)) # Semakin besar nilainya, semakin konservatif/simpel modelnya


# Hyperparam space XGboost
hyperparam_space_xgb = {
    'model__max_depth': max_depth, 
    'model__learning_rate': learning_rate,
    'model__n_estimators': n_estimators,
    'model__subsample': subsample,
    'model__gamma': gamma,
    'model__colsample_bytree': colsample_bytree,
    'model__reg_alpha': reg_alpha
}

# %%
# Benchmark model dengan hyperparameter tuning
xgb = XGBRegressor(random_state=1, verbosity=0)

# Membuat algorithm chains
estimator_xgb = Pipeline([
        ('preprocessing', transformer),
        ('scaler', scaler),
        ('model', xgb)
        ])

crossval = KFold(n_splits=5, shuffle=True, random_state=1)

# Hyperparameter tuning
random_xgb = RandomizedSearchCV(
    estimator_xgb, 
    param_distributions = hyperparam_space_xgb,
    n_iter = 50,
    cv = crossval, 
    scoring = ['neg_root_mean_squared_error', 'neg_mean_absolute_error'], 
    n_jobs = -1,
    refit = 'neg_root_mean_squared_error', # Hanya bisa memilih salah stau metric untuk optimisasi
    random_state = 1  
)

# %%
# Fitting data training untuk mencari parameter terbaik
random_xgb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('One '
#                                                                                'Hot',
#                                                                                OneHotEncoder(drop='first'),
#                                                                                ['Gear_Type',
#                                                                                 'Origin',
#                                                                                 'Options']),
#                                                                               ('Binary',
#                                                                                BinaryEncoder(),
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan RMSE dan MAE
pd.DataFrame(random_xgb.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error']).head()
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7        0.568330      0.015179         0.042028        0.011445
# 17       0.379246      0.020635         0.028953        0.002937
# 22       0.256219      0.043967         0.030450        0.008867
# 23       0.287279      0.038156         0.032681        0.004053
# 3        0.532554      0.068219         0.045024        0.008927
#
#     param_model__subsample  param_model__reg_alpha  param_model__n_estimators  \
# 7                      0.9                0.059948                        119
# 17                     0.6                0.001000                        190
# 22                     0.7                0.002783                        155
# 23                     0.9                3.593814                        153
# 3                      0.5                0.021544                        166
#
#     param_model__max_depth  param_model__learning_rate  param_model__gamma  \
# ...

# %%
# Cek skor dan params terbaik
print('XGBoost')
print('Best_score:', random_xgb.best_score_)
print('Best_params:', random_xgb.best_params_)
# Out:
# XGBoost
# Best_score: -20946.401856015727
# Best_params: {'model__subsample': np.float64(0.9), 'model__reg_alpha': np.float64(0.05994842503189409), 'model__n_estimators': np.int64(119), 'model__max_depth': np.int64(8), 'model__learning_rate': np.float64(0.05), 'model__gamma': np.int64(5), 'model__colsample_bytree': np.float64(0.8)}

# %% [markdown]
# ### Predict To Test Set Whit The Tuned Model

# %%
# Model XGBoost
model = {'XGB': XGBRegressor(random_state=1)}

# Define model terhadap estimator terbaik
xgb_tuning = random_xgb.best_estimator_

# Fitting model
xgb_tuning.fit(X_train, y_train)

# Predict test set
y_pred_xgb_tuning = xgb_tuning.predict(X_test)

# Simpan nilai metrics RMS dan MAE setelah tuning
rmse_xgb_tuning = np.sqrt(mean_squared_error(y_test, y_pred_xgb_tuning))
mae_xgb_tuning = mean_absolute_error(y_test, y_pred_xgb_tuning)

score_after_tuning = pd.DataFrame({'RMSE': rmse_xgb_tuning, 'MAE': mae_xgb_tuning}, index=model.keys())
score_after_tuning
# Out:
#              RMSE           MAE
# XGB  19794.693672  12672.325229

# %% [markdown]
# ### Performance Comparation

# %%
# Sebelum hyperparameter tuning
pd.DataFrame(score_before_tuning.loc['XGB']).T
# Out:
#              RMSE           MAE
# XGB  20522.370712  13744.589779

# %%
# Setelah hyperparameter tuning
score_after_tuning
# Out:
#              RMSE           MAE
# XGB  19794.693672  12672.325229

# %% [markdown]
# Performa setelah di lakukan Hayperparameter Tuning mengalami peningkatan meski tidak siknifikan.
# - RMSE & MAE sebelum tunning : 20522 & 13744
# - RMSE & MAE sebelum tunning : 19794 & 12672

# %%
plt.figure(figsize=(14, 8))
plot = sns.scatterplot(x=y_test, y=y_pred_xgb_tuning).set(title='Actual vs. Prediction Price', 
                                               xlabel='Actual Price', 
                                               ylabel='Predicted Price');

# %% [markdown]
# ### **Kesimpulan dari Visualisasi Model After Tuning**
#
# Grafik yang ditampilkan adalah  membandingkan **harga aktual** (Actual Price) dengan **harga yang diprediksi** (Predicted Price) setelah tuning model. Berikut adalah analisisnya:
#
# #### **1. Tren Positif (Linear Relationship)**
# - model menunjukan peningkatan setealah di lakukan tunning
# - Sebagian besar titik-titik data mengikuti pola garis lurus diagonal, yang menunjukkan bahwa model memiliki hubungan linier antara harga aktual dan harga prediksi.
# - Modeld sudah cukup baik dalam menangkap pola dari data setelah dilakukan tuning.
#
# #### **2. Variabilitas dan Penyimpangan (Outliers)**
# - Terdapat beberapa **outliers (titik yang jauh dari pola utama)**, terutama pada nilai harga tinggi.
# - Ini menunjukkan bahwa model masih memiliki **kesalahan prediksi** pada beberapa titik, terutama di **harga yang lebih tinggi**, yang bisa disebabkan oleh kurangnya data atau fitur yang kurang informatif.
#
# #### **3. Performa Model**
# - Jika titik-titik **menyebar jauh dari garis diagonal (Actual = Predicted)**, maka model masih memiliki error yang cukup besar.
# - Namun, pada visualisasi ini, **mayoritas titik berada di sekitar garis diagonal**, menunjukkan bahwa model memberikan prediksi yang lebih akurat setelah tuning dibandingkan sebelum tuning.
#
# #### **4. Area dengan Kesalahan Lebih Besar**
# - Pada rentang harga rendah hingga menengah, model terlihat cukup baik dalam memprediksi harga.
# - Pada harga yang sangat tinggi, terdapat **lebih banyak variasi dan penyimpangan**, yang bisa menyebabkan error lebih besar.
#
# ---

# %% [markdown]
# #### **Feature Importances**

# %%
# Plot feature importances
feature_imp = pd.DataFrame(xgb_tuning['model'].feature_importances_, transformer.get_feature_names_out(),
                           columns=['Value']).sort_values(by='Value', ascending=False)

plt.figure(figsize=(10,8))
sns.barplot(data=feature_imp, x='Value', y=feature_imp.index)
# Out:
# <Axes: xlabel='Value', ylabel='None'>

# %% [markdown]
# ## **Congclusion**
# ---
# Pada model yang di pilih pada pembuatan `Machine Learning` adalah `XGBoostRegretion`, dari model tersebut akurasi di tingkatkan dengan menggunakan `Hyperparameter Tunning` meskipun begitu masih terdapat nilai *Outlier* yang umumnya terjadi pada **Price** (Harga) yang tinggi hal tersebut terjadi karena data memuat mobil dengan harga yang relatif lebih kecil sehingga hasil model sulit melakukan pemodelan pada harga yang tinggi sehingga menghasilkan error yang cukup besar.
#
# **Feature Importances** di atas menunjukan fitur yang paling berpengaruh adalah `engine size`, `make`,dan `year`.sedangkan origin, option dan gear type tidak terlalu berpengaruh. Hal tersebut sejalan karena umunya ketika ingin membeli mobil bekas umumnya kita akan mencari tahun paling muda dengan torsi kekuatan mobil yang tangguh, selain itu pabrikan pembuat mobil juga sangat berpengaruh, sebagaimana yang kita tahu umumnya di pasar mobil yang memiliki spesifikasi kurang lebih sama mungkin akan memiliki harga yang berbeda sesuai dengan segmentasi pasar masing-masing.
#
# **Matrix Evaluation** yang digunakan pada model adalah MRSE dan MAE, ditinjau dari nilai `MAE` yang di hasilkan model setelah Hyperparameter Tunning yaitu rata-rata besaran selisih dari harga asli dengan harga prediksi adalah 12,672 riyal, dari sini kita dapat menyimpulkan apa bila model yang kita gunakan untuk memprediski harga jual sebuh mobil maka diperkirakan memiliki rentang nilai seperti terhadap model ( Maksimal harga 182,331 Riyal). Meskipun begitu masih terdapat kemungkinan bahwa harga bisa melebihi 12,672 riyal atau kurang sebagai mana yang terlihat pada visualisasi terdapat nilai Outlier yang tinggi. Bias pada hasil model dapat terjadi karena terbatasnya fitur dan mungkin terdapat beberapa faktor lainnya. Kedepannya bisa di lakukan A/B testing sebagai insight terkait fitur yang mempengaruhi model.
#
# Model dapat di jadikan acuan bagi pengusaha untuk menentukan mobil mana yang nantinya akan di beli yang di sesuaikan dengan kebutuhan. Dari hasil tersebut pengusaha juga dapat mengukur apa nominal yang di keluakan untuk mobil bekas tersebut masih termasuk dari nilai error atau tidak. meskipun begitu nilai error yang tidak terlalu tinggi masih dapat menguntungkan bagi perusahaan karena mobil tersebut di sewakan untuk menghasilkam profit kembali.
#
# ---

# %% [markdown]
# ## **Recomendation**
#
# ### **1. Rekomendasi Bisnis:**
#  - Saat melakukan pembelian mobil perhatikan ukuran mesin mobil, pabrikan pembutana mobil, dan tahun  hal tersebut dapat menentukan stabilitas harga mobil sehinggi ketahanan mobil saat di sewakan nantinya akan menguntungkan dan saat di jual kembali mobil sebaiknya mobil di naikan 10,000 - 12,000 riyal dari harga machine learning, sehingga saat negosiasi harga dapat di sesuaikan.
#
#  - Pengusaha yang ingin membeli mobil untuk di sewakan sebaiknya menawar lebih rendah dari harga yang di rekomendasikan, terlebih nantinya mobil tresbeut di gunakan untuk penyewaan sebaiknya memilih mobil dengan kondisi mesin yang sehat. jika di hitung pada harga maksimal dengan selisih harga dari yang di modelkan terdapat jarak 3,8%. nilai tersebut dapat di jadikan acuan saat melakukan penawaran dalam pembelian mobil.
#
#  - Pembelian mobil bekas sebaiknya juga dikombinasikan dengan mobil baru. berdasakan model tahun pembuatan menjadi faktor yang menentukan sebuah harga mobil, dalam kata lain, semakin muda tahun pembuatannya semakin mahal mobilnya, sehingga sebaiknya mobil dengan harga mobil bekas yang tidak berbeda jauh sebaiknya diganti dengan mobil yang lebih baru.
#
# ### **2.Rekomendasi Model:**
#  - Penambahan fitur-fitur yang dapat membantu dalam membuat menentukan harga dengan lebih akurat. fitur yang dapat di tambahkan seperti, kapasitas mobil, fitur yang di berikan, mobil listrik atau bensin dan masih banyak lainnya.
#
#  - Meningkatkan kualitas data sebelum di lakukan pemodelan seperti feature enginering yang lebih informatif, melakukan encoding yang dapat di sederhanakan, menangani outlier  pada target dan fitur.
#
#  - Melakukan modeling lain untuk memberikan lebih banyak opsi dapa pemodelan
#
#  - Pengecekan korelasi antar fitur dengan metode VIF pada masing-masing fitur.
#
#  - Terdapat nilai yang mungkin tidak termasuk pada nilai outlier, meskipun begitu nominal yang di rata-ratakan masih tidak singkron pada harga mobil yang umumnya ada di arab saudi. Dapat di lakukan juga dengan melakukan metode polinomial untuk meningkatkan nilai fitur. Selain itu kita dapat mengelompokan error yang ekstream

# %% [markdown]
# ## **SAVE MODE**

# %%
import pickle

best_model = xgb_tuning #Model Terbaik

with open('Used_Cars_Arab_Saudi.pkl','wb') as f:
   pickle.dump(best_model, f)

print("Model disimpan.")
# Out:
# Model disimpan.

# %%
# Load model
filename = 'Used_Cars_Arab_Saudi.pkl'
loaded_model = pickle.load(open(filename, 'rb'))

# %%
np.sqrt(mean_squared_error(y_test, loaded_model.predict(X_test)))
# Out:
# np.float64(19794.693672302932)

# %% [markdown]
# **Melakukan Testing Model yang di Simpan**

# %%
TespPredict = pd.DataFrame({
    'Type':['Yukon'],
    'Region':['Abha'],
    'Make':['GMC'],
    'Gear_Type':['Automatic'],
    'Origin':['Gulf Arabic'],
    'Options':['Full'],
    'Year':[2020],
    'Engine_Size':[8.0],
    'Mileage':[10000]
})

TespPredict
# Out:
#     Type Region Make  Gear_Type       Origin Options  Year  Engine_Size  \
# 0  Yukon   Abha  GMC  Automatic  Gulf Arabic    Full  2020          8.0
#
#    Mileage
# 0    10000

# %%
loaded_model.predict(TespPredict)
# Out:
# array([151869.69], dtype=float32)

# %% [markdown]
# Berdasarkan model kita dapat membeli mobil dengan harga 151,869 riyal, sebaiknya harag tersebut dapat di turunkan kembali 10-5% dari harga yang di prediksikan agar lebih menguntungkan, selain itu nila tersebut dapat di buat untuk meningkatkan fitur atau kenayaman dalam berkendaraan sebelum di lakukan penyewaan.
